# %% [markdown]
# # Reverse Search Engine
# Given an image,the goal is to retrieve the top-k similar images from a database at speed.

# %%
import torch
import torchvision
import torchvision.models as models
from PIL import Image

# Load the pretrained model
model = models.resnet18(pretrained=True)

# Use the model object to select the desired layer
layer = model._modules.get('avgpool')

# Set model to evaluation mode
model.eval()

transforms = torchvision.transforms.Compose([
    torchvision.transforms.Resize(256),
    torchvision.transforms.CenterCrop(224),
    torchvision.transforms.ToTensor(),
    torchvision.transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]),
])


def get_vector(image):
    # Create a PyTorch tensor with the transformed image
    t_img = transforms(image)
    # Create a vector of zeros that will hold our feature vector
    # The 'avgpool' layer has an output size of 512
    my_embedding = torch.zeros(512)

    # Define a function that will copy the output of a layer
    def copy_data(m, i, o):
        my_embedding.copy_(o.flatten())                 # <-- flatten

    # Attach that function to our selected layer
    h = layer.register_forward_hook(copy_data)
    # Run the model on our transformed image
    with torch.no_grad():                               # <-- no_grad context
        model(t_img.unsqueeze(0))                       # <-- unsqueeze
    # Detach our copy function from the layer
    h.remove()
    # Return the feature vector
    return my_embedding
# Out:
# Downloading: "https://download.pytorch.org/models/resnet18-f37072fd.pth" to /root/.cache/torch/hub/checkpoints/resnet18-f37072fd.pth
#   0%|          | 0.00/44.7M [00:00<?, ?B/s]

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

df = pd.read_csv('data.csv')
df['article_id_path'] = df['article_id'].apply(lambda x: '0' + str(x) + '.jpg')

# %%
import os
def get_vector_for_image(article_id_path,product_type_name):
  img_path = os.path.join('/content/drive/MyDrive/data/',product_type_name,article_id_path)
  img = Image.open(img_path)
  vector = get_vector(img)
  return vector
  
df['Embeddings'] = df.apply(lambda x: get_vector_for_image(x.article_id_path,x.product_type_name), axis = 1)

# %%
# Save as a pickle for future processing
df.to_pickle('Embeddings-1000.pkl')

# %%
# !pip install annoy
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting annoy
#   Downloading annoy-1.17.0.tar.gz (646 kB)
#      |████████████████████████████████| 646 kB 5.3 MB/s
# Building wheels for collected packages: annoy
#   Building wheel for annoy (setup.py) ... done
#   Created wheel for annoy: filename=annoy-1.17.0-cp37-cp37m-linux_x86_64.whl size=391576 sha256=ddd8d0a91ba9e05a546e2a96a19b5dac741f0093d76fd523fbbb095ca56de729
#   Stored in directory: /root/.cache/pip/wheels/4f/e8/1e/7cc9ebbfa87a3b9f8ba79408d4d31831d67eea918b679a4c07
# Successfully built annoy
# Installing collected packages: annoy
# Successfully installed annoy-1.17.0

# %%
from annoy import AnnoyIndex
f = len(df['Embeddings'][0])
t = AnnoyIndex(f, metric='euclidean')

ntree = 500 # hyper-parameter, the more the number of trees better the prediction
for i, vector in enumerate(df['Embeddings']):
    t.add_item(i, vector)
_  = t.build(ntree)

# %%
df
# Out:
#      article_id  product_code               prod_name  product_type_no  \
# 0     625189002        625189   SB Sebastian rain jkt              262
# 1     801905013        801905  Tom Chino Shorts (TVP)              274
# 2     637922006        637922       Brian Tuxedo Coat              262
# 3     698111001        698111           Solene shorts              274
# 4     636469001        636469          kourtny shorts              274
# ..          ...           ...                     ...              ...
# 995   729948001        729948         OC Rachel Skirt              275
# 996   791445002        791445             Fargo tunic              258
# 997   658459001        658459         Jogger lined 79              272
# 998   741417001        741417        SPEED Kasuma 3-p              272
# 999   728156014        728156            Robin blazer              264
#
#     product_type_name  product_group_name  graphical_appearance_no  \
# 0              Jacket  Garment Upper body                  1010016
# 1              Shorts  Garment Lower body                  1010001
# 2              Jacket  Garment Upper body                  1010016
# 3              Shorts  Garment Lower body                  1010018
# 4              Shorts  Garment Lower body                  1010016
# ..                ...                 ...                      ...
# 995             Skirt  Garment Lower body                  1010016
# 996            Blouse  Garment Upper body                  1010016
# 997          Trousers  Garment Lower body                  1010023
# 998          Trousers  Garment Lower body                  1010016
# 999            Blazer  Garment Upper body                  1010016
#
#     graphical_appearance_name  colour_group_code colour_group_name  ...  \
# 0                       Solid                 73         Dark Blue  ...
# 1            All over pattern                 13             Beige  ...
# 2                       Solid                  9             Black  ...
# 3                   Treatment                 71        Light Blue  ...
# 4                       Solid                  9             Black  ...
# ..                        ...                ...               ...  ...
# 995                     Solid                 71        Light Blue  ...
# 996                     Solid                 31      Light Orange  ...
# 997                     Denim                 73         Dark Blue  ...
# 998                     Solid                 73         Dark Blue  ...
# 999                     Solid                 51        Light Pink  ...
#
#                  index_name index_group_no  index_group_name section_no  \
# 0     Children Sizes 92-140              4     Baby/Children         45
# 1     Children Sizes 92-140              4     Baby/Children         46
# 2                Ladieswear              1        Ladieswear         19
# 3    Children Sizes 134-170              4     Baby/Children         77
# 4                   Divided              2           Divided         53
# ..                      ...            ...               ...        ...
# 995                 Divided              2           Divided         50
# 996              Ladieswear              1        Ladieswear          8
# 997   Children Sizes 92-140              4     Baby/Children         46
# 998        Baby Sizes 50-98              4     Baby/Children         41
# 999              Ladieswear              1        Ladieswear         11
#
#            section_name garment_group_no             garment_group_name  \
# 0        Kids Outerwear             1007                        Outdoor
# 1              Kids Boy             1025                         Shorts
# 2        Womens Jackets             1007                        Outdoor
# 3            Young Girl             1005                   Jersey Fancy
# 4    Divided Collection             1025                         Shorts
# ..                  ...              ...                            ...
# 995    Divided Projects             1009                       Trousers
# 996                Mama             1010                        Blouses
# 997            Kids Boy             1016                 Trousers Denim
# 998            Baby Boy             1006  Woven/Jersey/Knitted mix Baby
# 999    Womens Tailoring             1008                        Dressed
#
#                                            detail_desc  article_id_path  \
# 0    Rain jacket in windproof, waterproof functiona...   0625189002.jpg
# 1    Knee-length shorts in washed cotton twill with...   0801905013.jpg
# 2    Fitted coat in woven fabric with a tuxedo-styl...   0637922006.jpg
# 3    Shorts in stretch jersey with a denim look mad...   0698111001.jpg
# 4    Short, high-waisted twill shorts in a cotton b...   0636469001.jpg
# ..                                                 ...              ...
# 995  Knee-length skirt in a cotton weave with brode...   0729948001.jpg
# 996  Tunic in an airy weave with a V-neck, yoke wit...   0791445002.jpg
# 997  Joggers in washed denim with an elasticated dr...   0658459001.jpg
# 998  Trousers in cotton twill with an adjustable el...   0741417001.jpg
# 999  Straight-cut jacket in woven fabric with a sha...   0728156014.jpg
#
#                                             Embeddings
# 0    [tensor(0.9268), tensor(2.1596), tensor(0.3360...
# 1    [tensor(0.9887), tensor(0.4870), tensor(0.), t...
# 2    [tensor(0.3852), tensor(0.3776), tensor(0.1682...
# 3    [tensor(1.3565), tensor(0.2290), tensor(0.0044...
# 4    [tensor(1.0613), tensor(0.0666), tensor(0.0711...
# ..                                                 ...
# 995  [tensor(1.4451), tensor(1.6120), tensor(0.0660...
# 996  [tensor(0.4417), tensor(0.1949), tensor(0.0401...
# 997  [tensor(0.3145), tensor(1.6253), tensor(0.0438...
# 998  [tensor(0.0369), tensor(0.2694), tensor(0.2917...
# 999  [tensor(1.3273), tensor(1.2449), tensor(0.1245...
#
# [1000 rows x 27 columns]

# %%
import time
def get_similar_images_annoy(img_index):
    start = time.time()
    base_img_id, base_vector, base_label  = df.iloc[img_index, [0,-1,4]]
    similar_img_ids = t.get_nns_by_item(img_index, 5)
    end = time.time()
    print(f'{(end - start) * 1000} ms')
    return base_img_id, base_label, df.iloc[similar_img_ids]

# %%
base_image, base_label, similar_images_df = get_similar_images_annoy(0)
# Out:
# 4.379510879516602 ms

# %%
similar_images_df
# Out:
#      article_id  product_code              prod_name  product_type_no  \
# 0     625189002        625189  SB Sebastian rain jkt              262
# 870   564472001        564472  BB Nick varsity speed              262
# 981   803662001        803662        CARTER PU SHIRT              259
# 639   477163001        477163              Shaun (1)              308
# 323   569974001        569974   DONT USE ROLAND HOOD              308
#
#     product_type_name  product_group_name  graphical_appearance_no  \
# 0              Jacket  Garment Upper body                  1010016
# 870            Jacket  Garment Upper body                  1010016
# 981             Shirt  Garment Upper body                  1010016
# 639            Hoodie  Garment Upper body                  1010016
# 323            Hoodie  Garment Upper body                  1010016
#
#     graphical_appearance_name  colour_group_code colour_group_name  ...  \
# 0                       Solid                 73         Dark Blue  ...
# 870                     Solid                  9             Black  ...
# 981                     Solid                  9             Black  ...
# 639                     Solid                  9             Black  ...
# 323                     Solid                  9             Black  ...
#
#                  index_name index_group_no  index_group_name section_no  \
# 0     Children Sizes 92-140              4     Baby/Children         45
# 870  Children Sizes 134-170              4     Baby/Children         45
# 981                 Divided              2           Divided         53
# 639                Menswear              3          Menswear         31
# 323                Menswear              3          Menswear         26
#
#            section_name garment_group_no garment_group_name  \
# 0        Kids Outerwear             1007            Outdoor
# 870      Kids Outerwear             1007            Outdoor
# 981  Divided Collection             1010            Blouses
# 639      Mens Outerwear             1007            Outdoor
# 323       Men Underwear             1002       Jersey Basic
#
#                                            detail_desc  article_id_path  \
# 0    Rain jacket in windproof, waterproof functiona...   0625189002.jpg
# 870  Baseball jacket in woven fabric with a sheen. ...   0564472001.jpg
# 981  Straight-cut shirt in imitation leather with a...   0803662001.jpg
# 639  Windbreaker in woven fabric with a mesh-lined,...   0477163001.jpg
# 323  Top in sweatshirt fabric with a lined drawstri...   0569974001.jpg
#
#                                             Embeddings
# 0    [tensor(0.9268), tensor(2.1596), tensor(0.3360...
# 870  [tensor(1.0939), tensor(1.4100), tensor(0.1328...
# 981  [tensor(0.9985), tensor(2.7406), tensor(0.4034...
# 639  [tensor(0.7147), tensor(2.5043), tensor(0.4261...
# 323  [tensor(1.3733), tensor(2.4662), tensor(0.0945...
#
# [5 rows x 27 columns]
